# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import re
import itertools
from bs4 import BeautifulSoup
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords, wordnet as wn
from nltk.stem import WordNetLemmatizer
import nltk
from collections import defaultdict
from sklearn.model_selection import KFold
from imblearn.over_sampling import RandomOverSampler
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, SpatialDropout1D
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt

# Load your dataset
dataset = pd.read_csv('annotated_comments_binary.csv', encoding='latin-1')
print("Dataset loaded.")

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
nltk.download('omw-1.4')
print("NLTK data downloaded.")

# Define preprocessing functions
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

def remove_url(text):
    return re.sub(r'^https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)

def clean_text(text):
    REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\<\>\|@,;]')
    BAD_SYMBOLS_RE = re.compile('[^0-9a-z =#?+_]')
    text = strip_html(text) 
    text = remove_url(text)
    text = text.lower() 
    text = REPLACE_BY_SPACE_RE.sub(' ', text) 
    text = BAD_SYMBOLS_RE.sub('', text) 
    return text

# Preprocess dataset
dataset['comment_Text'] = dataset['comment_Text'].apply(clean_text)
dataset['comment_Text'].dropna(inplace=True)
dataset['comment_Text'] = [entry.lower() for entry in dataset['comment_Text']]
dataset['comment_Text'] = [word_tokenize(entry) for entry in dataset['comment_Text']]

tag_map = defaultdict(lambda: wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV

for index, entry in enumerate(dataset['comment_Text']):
    Final_words = []
    word_Lemmatized = WordNetLemmatizer()
    for word, tag in pos_tag(entry):
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word, tag_map[tag[0]])
            Final_words.append(word_Final)
    dataset.loc[index, 'text_final'] = str(Final_words)

# Map 'Yes'/'No' to 1/0
dataset['Have_Sarcasm'] = dataset['Have_Sarcasm'].map({'Yes': 1, 'No': 0})

# Apply oversampling to balance the classes
X = dataset['text_final']
y = dataset['Have_Sarcasm']
oversampler = RandomOverSampler(random_state=42)
X_resampled, y_resampled = oversampler.fit_resample(np.array(X).reshape(-1, 1), y)

# Set parameters for the model
max_words = 1000
max_len = 150

# Define the LSTM model
def build_LSTM_model():
    model = Sequential()
    model.add(Embedding(max_words, 100, input_length=max_len))
    model.add(SpatialDropout1D(0.2))
    model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Instantiate the model
lstm_model = build_LSTM_model()

# Function to perform training and evaluation
def get_dataset_words_frequency(X_resampled, y_resampled, max_words, max_len):
    k = 5
    kf = KFold(n_splits=k, shuffle=True, random_state=1)
    acc_score = []
    all_predictions = []
    all_actuals = []

    for train_index, test_index in kf.split(X_resampled):
        Train_X, Test_X = X_resampled[train_index], X_resampled[test_index]
        Train_Y, Test_Y = y_resampled[train_index], y_resampled[test_index]

        Train_X = [x[0] for x in Train_X]
        Test_X = [x[0] for x in Test_X]

        # Tokenization and padding of sequences
        tok = Tokenizer(num_words=max_words)
        tok.fit_on_texts(Train_X)
        sequences = tok.texts_to_sequences(Train_X)
        sequences_matrix = pad_sequences(sequences, maxlen=max_len)

        # Train the model
        history = lstm_model.fit(sequences_matrix, Train_Y, batch_size=100, epochs=10, validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss', min_delta=0.0001)])
        
        # Predict and evaluate
        test_sequences = tok.texts_to_sequences(Test_X)
        test_sequences_matrix = pad_sequences(test_sequences, maxlen=max_len)
        predictions = lstm_model.predict(test_sequences_matrix).round().flatten()
        acc_score.append(accuracy_score(Test_Y, predictions))
        all_predictions.extend(predictions)
        all_actuals.extend(Test_Y)

    avg_acc_score = sum(acc_score) / k
    print('Avg accuracy : {}'.format(avg_acc_score))
    return history, np.array(all_predictions), np.array(all_actuals)

# Train the model and get the history object, predictions, and actual values
history, all_predictions, all_actuals = get_dataset_words_frequency(X_resampled, y_resampled, max_words, max_len)

import matplotlib.pyplot as plt

def plot_history(history):
    plt.figure(figsize=(12, 6))
    
    # Plot for model accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train')
    plt.plot(history.history['val_accuracy'], label='Validation')
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(loc='upper left')
    
    # Plot for model loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train')
    plt.plot(history.history['val_loss'], label='Validation')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(loc='upper left')
    
    # Save the figure before showing
    plt.savefig('training_validation_loss_accuracy_lstm.png', dpi=300)
    
    plt.show()


plot_history(history)

from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import itertools
import numpy as np

# Function to plot confusion matrix
def plot_confusion_matrix(y_true, y_pred, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))  # Optional: Define the figure size
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.savefig('confusion_matrix_lstm.png', dpi=300)  # Save the plot with 300 DPI
    plt.show()

# Example usage:
# plot_confusion_matrix(y_true, y_pred, classes=['Class 1', 'Class 2'], title='Confusion matrix')


from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Plotting ROC curve
def plot_roc_curve(y_true, y_pred_proba):
    fpr, tpr, _ = roc_curve(y_true, y_pred_proba)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.savefig('ROC_curve.png', dpi=300)  # Save the plot with 300 DPI
    plt.show()

# Example usage:
# plot_roc_curve(y_true, y_pred_proba)


# Plot the confusion matrix and ROC curve
plot_confusion_matrix(all_actuals, all_predictions, classes=["No Sarcasm", "Sarcasm"])
plot_roc_curve(all_actuals, all_predictions)

# Print classification report
print(classification_report(all_actuals, all_predictions))
# Out:
# Dataset loaded.
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/nekdilkhan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/nekdilkhan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/nekdilkhan/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/nekdilkhan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/nekdilkhan/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# /var/folders/y0/23chrxcn0d9dv4pxp6v708kr0000gn/T/ipykernel_1927/3880375010.py:38: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, "html.parser")
# NLTK data downloaded.
# Epoch 1/10
# 84/84 [==============================] - 199s 2s/step - loss: 0.5422 - accuracy: 0.7187 - val_loss: 0.2335 - val_accuracy: 0.9216
# Epoch 2/10
# 84/84 [==============================] - 189s 2s/step - loss: 0.1655 - accuracy: 0.9483 - val_loss: 0.2201 - val_accuracy: 0.9169
# Epoch 3/10
# 84/84 [==============================] - 126s 1s/step - loss: 0.1038 - accuracy: 0.9659 - val_loss: 0.1488 - val_accuracy: 0.9470
# Epoch 4/10
# 84/84 [==============================] - 112s 1s/step - loss: 0.0885 - accuracy: 0.9729 - val_loss: 0.1290 - val_accuracy: 0.9551
# Epoch 5/10
# 84/84 [==============================] - 119s 1s/step - loss: 0.0737 - accuracy: 0.9767 - val_loss: 0.1204 - val_accuracy: 0.9670
# Epoch 6/10
# 84/84 [==============================] - 118s 1s/step - loss: 0.0695 - accuracy: 0.9790 - val_loss: 0.1102 - val_accuracy: 0.9689
# Epoch 7/10
# 84/84 [==============================] - 89s 1s/step - loss: 0.0657 - accuracy: 0.9785 - val_loss: 0.0783 - val_accuracy: 0.9804
# Epoch 8/10
# 84/84 [==============================] - 86s 1s/step - loss: 0.0599 - accuracy: 0.9810 - val_loss: 0.1245 - val_accuracy: 0.9661
# 82/82 [==============================] - 6s 72ms/step
# Epoch 1/10
# 84/84 [==============================] - 88s 1s/step - loss: 0.4940 - accuracy: 0.8092 - val_loss: 0.3692 - val_accuracy: 0.8557
# Epoch 2/10
# 84/84 [==============================] - 96s 1s/step - loss: 0.1489 - accuracy: 0.9532 - val_loss: 0.1776 - val_accuracy: 0.9374
# Epoch 3/10
# 84/84 [==============================] - 108s 1s/step - loss: 0.1074 - accuracy: 0.9691 - val_loss: 0.1716 - val_accuracy: 0.9403
# Epoch 4/10
# 84/84 [==============================] - 85s 1s/step - loss: 0.0876 - accuracy: 0.9725 - val_loss: 0.0999 - val_accuracy: 0.9608
# Epoch 5/10
# 84/84 [==============================] - 71s 853ms/step - loss: 0.0777 - accuracy: 0.9757 - val_loss: 0.0754 - val_accuracy: 0.9737
# Epoch 6/10
# 84/84 [==============================] - 79s 941ms/step - loss: 0.0688 - accuracy: 0.9777 - val_loss: 0.0881 - val_accuracy: 0.9675
# 82/82 [==============================] - 7s 83ms/step
# Epoch 1/10
# 84/84 [==============================] - 94s 1s/step - loss: 0.3716 - accuracy: 0.8558 - val_loss: 0.2668 - val_accuracy: 0.8992
# Epoch 2/10
# 84/84 [==============================] - 76s 906ms/step - loss: 0.1242 - accuracy: 0.9588 - val_loss: 0.1642 - val_accuracy: 0.9455
# Epoch 3/10
# 84/84 [==============================] - 73s 871ms/step - loss: 0.0850 - accuracy: 0.9724 - val_loss: 0.1472 - val_accuracy: 0.9498
# Epoch 4/10
# 84/84 [==============================] - 70s 827ms/step - loss: 0.0739 - accuracy: 0.9761 - val_loss: 0.0739 - val_accuracy: 0.9752
# Epoch 5/10
# 84/84 [==============================] - 65s 775ms/step - loss: 0.0637 - accuracy: 0.9785 - val_loss: 0.0987 - val_accuracy: 0.9694
# 82/82 [==============================] - 5s 66ms/step
# Epoch 1/10
# 84/84 [==============================] - 92s 1s/step - loss: 0.4568 - accuracy: 0.8188 - val_loss: 0.3954 - val_accuracy: 0.8161
# Epoch 2/10
# 84/84 [==============================] - 137s 2s/step - loss: 0.1543 - accuracy: 0.9466 - val_loss: 0.1535 - val_accuracy: 0.9431
# Epoch 3/10
# 84/84 [==============================] - 177s 2s/step - loss: 0.0965 - accuracy: 0.9694 - val_loss: 0.1289 - val_accuracy: 0.9527
# Epoch 4/10
# 84/84 [==============================] - 135s 2s/step - loss: 0.0767 - accuracy: 0.9755 - val_loss: 0.1083 - val_accuracy: 0.9642
# Epoch 5/10
# 84/84 [==============================] - 146s 2s/step - loss: 0.0652 - accuracy: 0.9777 - val_loss: 0.0947 - val_accuracy: 0.9713
# Epoch 6/10
# 84/84 [==============================] - 150s 2s/step - loss: 0.0575 - accuracy: 0.9809 - val_loss: 0.0704 - val_accuracy: 0.9804
# Epoch 7/10
# 84/84 [==============================] - 155s 2s/step - loss: 0.0549 - accuracy: 0.9805 - val_loss: 0.0686 - val_accuracy: 0.9804
# Epoch 8/10
# 84/84 [==============================] - 179s 2s/step - loss: 0.0498 - accuracy: 0.9829 - val_loss: 0.0840 - val_accuracy: 0.9761
# 82/82 [==============================] - 11s 134ms/step
# Epoch 1/10
# 84/84 [==============================] - 136s 2s/step - loss: 0.5378 - accuracy: 0.7771 - val_loss: 0.3766 - val_accuracy: 0.8232
# Epoch 2/10
# 84/84 [==============================] - 126s 2s/step - loss: 0.1924 - accuracy: 0.9312 - val_loss: 0.2188 - val_accuracy: 0.9121
# Epoch 3/10
# 84/84 [==============================] - 72s 854ms/step - loss: 0.1111 - accuracy: 0.9646 - val_loss: 0.1354 - val_accuracy: 0.9451
# Epoch 4/10
# 84/84 [==============================] - 71s 843ms/step - loss: 0.0813 - accuracy: 0.9726 - val_loss: 0.0995 - val_accuracy: 0.9675
# Epoch 5/10
# 84/84 [==============================] - 63s 756ms/step - loss: 0.0656 - accuracy: 0.9796 - val_loss: 0.0921 - val_accuracy: 0.9732
# Epoch 6/10
# 84/84 [==============================] - 86s 1s/step - loss: 0.0574 - accuracy: 0.9815 - val_loss: 0.0956 - val_accuracy: 0.9775
# 82/82 [==============================] - 5s 67ms/step
# Avg accuracy : 0.9704088094444542
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      6539
#            1       0.98      0.96      0.97      6539
#
#     accuracy                           0.97     13078
#    macro avg       0.97      0.97      0.97     13078
# weighted avg       0.97      0.97      0.97     13078

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import re
import itertools
from bs4 import BeautifulSoup
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords, wordnet as wn
from nltk.stem import WordNetLemmatizer
import nltk
from collections import defaultdict
from sklearn.model_selection import KFold
from imblearn.under_sampling import RandomUnderSampler
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, SpatialDropout1D
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt

# Load your dataset
dataset = pd.read_csv('annotated_comments_binary.csv', encoding='latin-1')
print("Dataset loaded.")

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
nltk.download('omw-1.4')
print("NLTK data downloaded.")

# Define preprocessing functions
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

def remove_url(text):
    return re.sub(r'^https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)

def clean_text(text):
    REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\<\>\|@,;]')
    BAD_SYMBOLS_RE = re.compile('[^0-9a-z =#?+_]')
    text = strip_html(text) 
    text = remove_url(text)
    text = text.lower() 
    text = REPLACE_BY_SPACE_RE.sub(' ', text) 
    text = BAD_SYMBOLS_RE.sub('', text) 
    return text

# Preprocess dataset
dataset['comment_Text'] = dataset['comment_Text'].apply(clean_text)
dataset['comment_Text'].dropna(inplace=True)
dataset['comment_Text'] = [entry.lower() for entry in dataset['comment_Text']]
dataset['comment_Text'] = [word_tokenize(entry) for entry in dataset['comment_Text']]

tag_map = defaultdict(lambda: wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV

for index, entry in enumerate(dataset['comment_Text']):
    Final_words = []
    word_Lemmatized = WordNetLemmatizer()
    for word, tag in pos_tag(entry):
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word, tag_map[tag[0]])
            Final_words.append(word_Final)
    dataset.loc[index, 'text_final'] = str(Final_words)

# Map 'Yes'/'No' to 1/0
dataset['Have_Sarcasm'] = dataset['Have_Sarcasm'].map({'Yes': 1, 'No': 0})

# Apply undersampling to balance the classes
X = dataset['text_final']
y = dataset['Have_Sarcasm']
undersampler = RandomUnderSampler(random_state=42)
X_resampled, y_resampled = undersampler.fit_resample(np.array(X).reshape(-1, 1), y)

# Set parameters for the model
max_words = 1000
max_len = 150

# Define the LSTM model
def build_LSTM_model():
    model = Sequential()
    model.add(Embedding(max_words, 100, input_length=max_len))
    model.add(SpatialDropout1D(0.2))
    model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Instantiate the model
lstm_model = build_LSTM_model()

# Function to perform training and evaluation
def get_dataset_words_frequency(X_resampled, y_resampled, max_words, max_len):
    k = 5
    kf = KFold(n_splits=k, shuffle=True, random_state=1)
    acc_score = []
    all_predictions = []
    all_actuals = []

    for train_index, test_index in kf.split(X_resampled):
        Train_X, Test_X = X_resampled[train_index], X_resampled[test_index]
        Train_Y, Test_Y = y_resampled[train_index], y_resampled[test_index]

        Train_X = [x[0] for x in Train_X]
        Test_X = [x[0] for x in Test_X]

        # Tokenization and padding of sequences
        tok = Tokenizer(num_words=max_words)
        tok.fit_on_texts(Train_X)
        sequences = tok.texts_to_sequences(Train_X)
        sequences_matrix = pad_sequences(sequences, maxlen=max_len)

        # Train the model
        history = lstm_model.fit(sequences_matrix, Train_Y, batch_size=100, epochs=10, validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss', min_delta=0.0001)])
        
        # Predict and evaluate
        test_sequences = tok.texts_to_sequences(Test_X)
        test_sequences_matrix = pad_sequences(test_sequences, maxlen=max_len)
        predictions = lstm_model.predict(test_sequences_matrix).round().flatten()
        acc_score.append(accuracy_score(Test_Y, predictions))
        all_predictions.extend(predictions)
        all_actuals.extend(Test_Y)

    avg_acc_score = sum(acc_score) / k
    print('Avg accuracy : {}'.format(avg_acc_score))
    return history, np.array(all_predictions), np.array(all_actuals)

# Train the model and get the history object, predictions, and actual values
history, all_predictions, all_actuals = get_dataset_words_frequency(X_resampled, y_resampled, max_words, max_len)

# Plot training and validation accuracy and loss
def plot_history(history):
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

plot_history(history)

# Function to plot confusion matrix
def plot_confusion_matrix(y_true, y_pred, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = confusion_matrix(y_true, y_pred)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# Plotting ROC curve
def plot_roc_curve(y_true, y_pred_proba):
    fpr, tpr, _ = roc_curve(y_true, y_pred_proba)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.show()

# Plot the confusion matrix and ROC curve
plot_confusion_matrix(all_actuals, all_predictions, classes=["No Sarcasm", "Sarcasm"])
plot_roc_curve(all_actuals, all_predictions)

# Print classification report
print(classification_report(all_actuals, all_predictions))
# Out:
# Dataset loaded.
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/nekdilkhan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/nekdilkhan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/nekdilkhan/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/nekdilkhan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/nekdilkhan/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# /var/folders/y0/23chrxcn0d9dv4pxp6v708kr0000gn/T/ipykernel_1927/4145058259.py:38: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, "html.parser")
# NLTK data downloaded.
# Epoch 1/10
# 45/45 [==============================] - 46s 942ms/step - loss: 0.6258 - accuracy: 0.6416 - val_loss: 1.2381 - val_accuracy: 0.0821
# Epoch 2/10
# 45/45 [==============================] - 41s 909ms/step - loss: 0.4002 - accuracy: 0.8367 - val_loss: 0.7996 - val_accuracy: 0.5912
# Epoch 3/10
# 45/45 [==============================] - 41s 902ms/step - loss: 0.1881 - accuracy: 0.9379 - val_loss: 0.5210 - val_accuracy: 0.8132
# Epoch 4/10
# 45/45 [==============================] - 50s 1s/step - loss: 0.1155 - accuracy: 0.9630 - val_loss: 0.3133 - val_accuracy: 0.9025
# Epoch 5/10
# 45/45 [==============================] - 40s 903ms/step - loss: 0.0855 - accuracy: 0.9695 - val_loss: 0.2523 - val_accuracy: 0.9341
# Epoch 6/10
# 45/45 [==============================] - 41s 913ms/step - loss: 0.0857 - accuracy: 0.9704 - val_loss: 0.2249 - val_accuracy: 0.9395
# Epoch 7/10
# 45/45 [==============================] - 38s 842ms/step - loss: 0.0750 - accuracy: 0.9743 - val_loss: 0.2480 - val_accuracy: 0.9377
# 44/44 [==============================] - 3s 70ms/step
# Epoch 1/10
# 45/45 [==============================] - 41s 911ms/step - loss: 0.6502 - accuracy: 0.7355 - val_loss: 0.8763 - val_accuracy: 0.5099
# Epoch 2/10
# 45/45 [==============================] - 39s 872ms/step - loss: 0.3397 - accuracy: 0.8604 - val_loss: 0.7407 - val_accuracy: 0.6525
# Epoch 3/10
# 45/45 [==============================] - 37s 830ms/step - loss: 0.2191 - accuracy: 0.9192 - val_loss: 0.5339 - val_accuracy: 0.7987
# Epoch 4/10
# 45/45 [==============================] - 36s 811ms/step - loss: 0.1501 - accuracy: 0.9485 - val_loss: 0.3212 - val_accuracy: 0.8827
# Epoch 5/10
# 45/45 [==============================] - 32s 715ms/step - loss: 0.1159 - accuracy: 0.9603 - val_loss: 0.3556 - val_accuracy: 0.8827
# 44/44 [==============================] - 2s 53ms/step
# Epoch 1/10
# 45/45 [==============================] - 25s 557ms/step - loss: 0.5515 - accuracy: 0.7796 - val_loss: 0.9064 - val_accuracy: 0.6182
# Epoch 2/10
# 45/45 [==============================] - 26s 571ms/step - loss: 0.3133 - accuracy: 0.8708 - val_loss: 0.6308 - val_accuracy: 0.7383
# Epoch 3/10
# 45/45 [==============================] - 26s 585ms/step - loss: 0.1926 - accuracy: 0.9359 - val_loss: 0.4228 - val_accuracy: 0.8655
# Epoch 4/10
# 45/45 [==============================] - 25s 562ms/step - loss: 0.1420 - accuracy: 0.9533 - val_loss: 0.3053 - val_accuracy: 0.9134
# Epoch 5/10
# 45/45 [==============================] - 25s 562ms/step - loss: 0.1162 - accuracy: 0.9605 - val_loss: 0.3157 - val_accuracy: 0.9242
# 44/44 [==============================] - 3s 62ms/step
# Epoch 1/10
# 45/45 [==============================] - 27s 609ms/step - loss: 0.5997 - accuracy: 0.7346 - val_loss: 0.7395 - val_accuracy: 0.6408
# Epoch 2/10
# 45/45 [==============================] - 27s 599ms/step - loss: 0.3377 - accuracy: 0.8609 - val_loss: 0.4710 - val_accuracy: 0.8051
# Epoch 3/10
# 45/45 [==============================] - 27s 590ms/step - loss: 0.2099 - accuracy: 0.9230 - val_loss: 0.3578 - val_accuracy: 0.8637
# Epoch 4/10
# 45/45 [==============================] - 26s 589ms/step - loss: 0.1330 - accuracy: 0.9553 - val_loss: 0.2258 - val_accuracy: 0.9332
# Epoch 5/10
# 45/45 [==============================] - 28s 617ms/step - loss: 0.1018 - accuracy: 0.9666 - val_loss: 0.1956 - val_accuracy: 0.9477
# Epoch 6/10
# 45/45 [==============================] - 27s 597ms/step - loss: 0.0870 - accuracy: 0.9702 - val_loss: 0.1987 - val_accuracy: 0.9504
# 44/44 [==============================] - 2s 53ms/step
# Epoch 1/10
# 45/45 [==============================] - 27s 599ms/step - loss: 0.6299 - accuracy: 0.7353 - val_loss: 1.1248 - val_accuracy: 0.5262
# Epoch 2/10
# 45/45 [==============================] - 26s 586ms/step - loss: 0.3747 - accuracy: 0.8333 - val_loss: 0.8323 - val_accuracy: 0.5641
# Epoch 3/10
# 45/45 [==============================] - 28s 626ms/step - loss: 0.2370 - accuracy: 0.9020 - val_loss: 0.5512 - val_accuracy: 0.7653
# Epoch 4/10
# 45/45 [==============================] - 28s 615ms/step - loss: 0.1459 - accuracy: 0.9505 - val_loss: 0.4183 - val_accuracy: 0.8574
# Epoch 5/10
# 45/45 [==============================] - 26s 589ms/step - loss: 0.1029 - accuracy: 0.9641 - val_loss: 0.2750 - val_accuracy: 0.9224
# Epoch 6/10
# 45/45 [==============================] - 26s 574ms/step - loss: 0.0811 - accuracy: 0.9747 - val_loss: 0.1968 - val_accuracy: 0.9504
# Epoch 7/10
# 45/45 [==============================] - 27s 609ms/step - loss: 0.0749 - accuracy: 0.9747 - val_loss: 0.1890 - val_accuracy: 0.9594
# Epoch 8/10
# 45/45 [==============================] - 27s 591ms/step - loss: 0.0669 - accuracy: 0.9772 - val_loss: 0.1914 - val_accuracy: 0.9594
# 44/44 [==============================] - 3s 69ms/step
# Avg accuracy : 0.9450867052023121
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      3460
#            1       0.97      0.92      0.94      3460
#
#     accuracy                           0.95      6920
#    macro avg       0.95      0.95      0.95      6920
# weighted avg       0.95      0.95      0.95      6920

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import re
import itertools
from bs4 import BeautifulSoup
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords, wordnet as wn
from nltk.stem import WordNetLemmatizer
import nltk
from collections import defaultdict
from sklearn.model_selection import KFold
from imblearn.over_sampling import RandomOverSampler
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, SpatialDropout1D
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt

# Load your dataset
dataset = pd.read_csv('annotated_comments_binary.csv', encoding='latin-1')
print("Dataset loaded.")

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
nltk.download('omw-1.4')
print("NLTK data downloaded.")

# Define preprocessing functions
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

def remove_url(text):
    return re.sub(r'^https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)

def clean_text(text):
    REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\<\>\|@,;]')
    BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
    text = strip_html(text) 
    text = remove_url(text)
    text = text.lower() 
    text = REPLACE_BY_SPACE_RE.sub(' ', text) 
    text = BAD_SYMBOLS_RE.sub('', text) 
    return text

# Preprocess dataset
dataset['comment_Text'] = dataset['comment_Text'].apply(clean_text)
dataset['comment_Text'].dropna(inplace=True)
dataset['comment_Text'] = [entry.lower() for entry in dataset['comment_Text']]
dataset['comment_Text'] = [word_tokenize(entry) for entry in dataset['comment_Text']]

tag_map = defaultdict(lambda: wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV

for index, entry in enumerate(dataset['comment_Text']):
    Final_words = []
    word_Lemmatized = WordNetLemmatizer()
    for word, tag in pos_tag(entry):
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word, tag_map[tag[0]])
            Final_words.append(word_Final)
    dataset.loc[index, 'text_final'] = str(Final_words)

# Map 'Yes'/'No' to 1/0
dataset['Have_Sarcasm'] = dataset['Have_Sarcasm'].map({'Yes': 1, 'No': 0})

# Apply oversampling to balance the classes
X = dataset['text_final']
y = dataset['Have_Sarcasm']
oversampler = RandomOverSampler(random_state=42)
X_resampled, y_resampled = oversampler.fit_resample(np.array(X).reshape(-1, 1), y)

# Set parameters for the model
max_words = 1000
max_len = 150

# Define the LSTM model
def build_LSTM_model():
    model = Sequential()
    model.add(Embedding(max_words, 100, input_length=max_len))
    model.add(SpatialDropout1D(0.2))
    model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Instantiate the model
lstm_model = build_LSTM_model()

# Function to perform training and evaluation
def get_dataset_words_frequency(X_resampled, y_resampled, max_words, max_len):
    k = 5
    kf = KFold(n_splits=k, shuffle=True, random_state=1)
    acc_score = []
    all_predicted_targets = []
    all_actual_targets = []
    tprs = []
    mean_fpr = np.linspace(0, 1, 100)

    for train_index, test_index in kf.split(X_resampled):
        Train_X, Test_X = X_resampled[train_index], X_resampled[test_index]
        Train_Y, Test_Y = y_resampled[train_index], y_resampled[test_index]

        Train_X = [x[0] for x in Train_X]
        Test_X = [x[0] for x in Test_X]

        # Tokenization and padding of sequences
        tok = Tokenizer(num_words=max_words)
        tok.fit_on_texts(Train_X)
        sequences = tok.texts_to_sequences(Train_X)
        sequences_matrix = pad_sequences(sequences, maxlen=max_len)

        # Compile and train the model
        model = build_LSTM_model()
        model.fit(sequences_matrix, Train_Y, batch_size=100, epochs=10, validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss', min_delta=0.0001)])
        
        # Evaluate the model
        test_sequences = tok.texts_to_sequences(Test_X)
        test_sequences_matrix = pad_sequences(test_sequences, maxlen=max_len)
        predictions = model.predict(test_sequences_matrix).round().flatten()

        # ROC Curve
        fpr, tpr, _ = roc_curve(Test_Y, predictions)
        tprs.append(np.interp(mean_fpr, fpr, tpr))
        tprs[-1][0] = 0.0
        roc_auc = auc(fpr, tpr)
        
        # Store actual and predicted values
        all_predicted_targets.extend(predictions)
        all_actual_targets.extend(Test_Y)

    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)

    return mean_fpr, mean_tpr, mean_auc, all_predicted_targets, all_actual_targets

# Get ROC data
mean_fpr_lstm, mean_tpr_lstm, mean_auc_lstm, all_predictions_lstm, all_actuals_lstm = get_dataset_words_frequency(X_resampled, y_resampled, max_words, max_len)

# Plot ROC Curve
plt.figure()
plt.plot(mean_fpr_lstm, mean_tpr_lstm, color='blue', lw=2, label='ROC curve LSTM (area = %0.2f)' % mean_auc_lstm)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic for LSTM')
plt.legend(loc="lower right")
plt.show()

# Print classification report
print(classification_report(all_actuals_lstm, all_predictions_lstm))
# Out:
# Dataset loaded.
# NLTK data downloaded.
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/nekdilkhan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/nekdilkhan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/nekdilkhan/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/nekdilkhan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/nekdilkhan/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# /var/folders/y0/23chrxcn0d9dv4pxp6v708kr0000gn/T/ipykernel_1927/124467070.py:38: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, "html.parser")
# Epoch 1/10
# 84/84 [==============================] - 53s 611ms/step - loss: 0.5888 - accuracy: 0.6953 - val_loss: 0.4858 - val_accuracy: 0.7721
# Epoch 2/10
# 84/84 [==============================] - 52s 617ms/step - loss: 0.2503 - accuracy: 0.9143 - val_loss: 0.2436 - val_accuracy: 0.9116
# Epoch 3/10
# 84/84 [==============================] - 51s 608ms/step - loss: 0.1094 - accuracy: 0.9649 - val_loss: 0.1883 - val_accuracy: 0.9322
# Epoch 4/10
# 84/84 [==============================] - 51s 613ms/step - loss: 0.0869 - accuracy: 0.9736 - val_loss: 0.1547 - val_accuracy: 0.9446
# Epoch 5/10
# 84/84 [==============================] - 54s 642ms/step - loss: 0.0792 - accuracy: 0.9741 - val_loss: 0.1532 - val_accuracy: 0.9455
# Epoch 6/10
# 84/84 [==============================] - 54s 644ms/step - loss: 0.0715 - accuracy: 0.9768 - val_loss: 0.1293 - val_accuracy: 0.9575
# Epoch 7/10
# 84/84 [==============================] - 55s 652ms/step - loss: 0.0675 - accuracy: 0.9781 - val_loss: 0.1016 - val_accuracy: 0.9694
# Epoch 8/10
# 84/84 [==============================] - 56s 671ms/step - loss: 0.0669 - accuracy: 0.9775 - val_loss: 0.1344 - val_accuracy: 0.9575
# 82/82 [==============================] - 5s 56ms/step
# Epoch 1/10
# 84/84 [==============================] - 56s 646ms/step - loss: 0.5625 - accuracy: 0.6973 - val_loss: 0.3065 - val_accuracy: 0.8686
# Epoch 2/10
# 84/84 [==============================] - 53s 634ms/step - loss: 0.1593 - accuracy: 0.9473 - val_loss: 0.1278 - val_accuracy: 0.9594
# Epoch 3/10
# 84/84 [==============================] - 52s 618ms/step - loss: 0.1017 - accuracy: 0.9687 - val_loss: 0.1215 - val_accuracy: 0.9594
# Epoch 4/10
# 84/84 [==============================] - 54s 647ms/step - loss: 0.0901 - accuracy: 0.9702 - val_loss: 0.1290 - val_accuracy: 0.9537
# 82/82 [==============================] - 5s 54ms/step
# Epoch 1/10
# 84/84 [==============================] - 54s 629ms/step - loss: 0.5386 - accuracy: 0.7133 - val_loss: 0.2504 - val_accuracy: 0.9121
# Epoch 2/10
# 84/84 [==============================] - 53s 627ms/step - loss: 0.1544 - accuracy: 0.9475 - val_loss: 0.2240 - val_accuracy: 0.9197
# Epoch 3/10
# 84/84 [==============================] - 56s 668ms/step - loss: 0.0996 - accuracy: 0.9686 - val_loss: 0.1437 - val_accuracy: 0.9541
# Epoch 4/10
# 84/84 [==============================] - 53s 628ms/step - loss: 0.0857 - accuracy: 0.9736 - val_loss: 0.1409 - val_accuracy: 0.9551
# Epoch 5/10
# 84/84 [==============================] - 55s 654ms/step - loss: 0.0771 - accuracy: 0.9759 - val_loss: 0.1132 - val_accuracy: 0.9646
# Epoch 6/10
# 84/84 [==============================] - 58s 688ms/step - loss: 0.0703 - accuracy: 0.9780 - val_loss: 0.0992 - val_accuracy: 0.9723
# Epoch 7/10
# 84/84 [==============================] - 54s 643ms/step - loss: 0.0629 - accuracy: 0.9793 - val_loss: 0.1205 - val_accuracy: 0.9632
# 82/82 [==============================] - 5s 56ms/step
# Epoch 1/10
# 84/84 [==============================] - 57s 644ms/step - loss: 0.5655 - accuracy: 0.6957 - val_loss: 0.2722 - val_accuracy: 0.9083
# Epoch 2/10
# 84/84 [==============================] - 51s 603ms/step - loss: 0.1655 - accuracy: 0.9483 - val_loss: 0.1926 - val_accuracy: 0.9355
# Epoch 3/10
# 84/84 [==============================] - 58s 693ms/step - loss: 0.0994 - accuracy: 0.9686 - val_loss: 0.1652 - val_accuracy: 0.9479
# Epoch 4/10
# 84/84 [==============================] - 61s 729ms/step - loss: 0.0886 - accuracy: 0.9729 - val_loss: 0.1802 - val_accuracy: 0.9412
# 82/82 [==============================] - 5s 56ms/step
# Epoch 1/10
# 84/84 [==============================] - 72s 839ms/step - loss: 0.5898 - accuracy: 0.6890 - val_loss: 0.5590 - val_accuracy: 0.7186
# Epoch 2/10
# 84/84 [==============================] - 53s 628ms/step - loss: 0.2146 - accuracy: 0.9257 - val_loss: 0.1782 - val_accuracy: 0.9302
# Epoch 3/10
# 84/84 [==============================] - 51s 613ms/step - loss: 0.1087 - accuracy: 0.9670 - val_loss: 0.1125 - val_accuracy: 0.9637
# Epoch 4/10
# 84/84 [==============================] - 49s 582ms/step - loss: 0.0923 - accuracy: 0.9701 - val_loss: 0.1085 - val_accuracy: 0.9656
# Epoch 5/10
# 84/84 [==============================] - 53s 633ms/step - loss: 0.0788 - accuracy: 0.9747 - val_loss: 0.0776 - val_accuracy: 0.9795
# Epoch 6/10
# 84/84 [==============================] - 52s 621ms/step - loss: 0.0755 - accuracy: 0.9744 - val_loss: 0.1196 - val_accuracy: 0.9656
# 82/82 [==============================] - 4s 47ms/step
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      6539
#            1       0.98      0.94      0.96      6539
#
#     accuracy                           0.96     13078
#    macro avg       0.96      0.96      0.96     13078
# weighted avg       0.96      0.96      0.96     13078

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import re
import itertools
from bs4 import BeautifulSoup
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords, wordnet as wn
from nltk.stem import WordNetLemmatizer
import nltk
from collections import defaultdict
from sklearn.model_selection import KFold
from imblearn.under_sampling import RandomUnderSampler
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, SpatialDropout1D
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt

# Load your dataset
dataset = pd.read_csv('annotated_comments_binary.csv', encoding='latin-1')
print("Dataset loaded.")

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
nltk.download('omw-1.4')
print("NLTK data downloaded.")

# Define preprocessing functions
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

def remove_url(text):
    return re.sub(r'^https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)

def clean_text(text):
    REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\<\>\|@,;]')
    BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
    text = strip_html(text) 
    text = remove_url(text)
    text = text.lower() 
    text = REPLACE_BY_SPACE_RE.sub(' ', text) 
    text = BAD_SYMBOLS_RE.sub('', text) 
    return text

# Preprocess dataset
dataset['comment_Text'] = dataset['comment_Text'].apply(clean_text)
dataset['comment_Text'].dropna(inplace=True)
dataset['comment_Text'] = [entry.lower() for entry in dataset['comment_Text']]
dataset['comment_Text'] = [word_tokenize(entry) for entry in dataset['comment_Text']]

tag_map = defaultdict(lambda: wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV

for index, entry in enumerate(dataset['comment_Text']):
    Final_words = []
    word_Lemmatized = WordNetLemmatizer()
    for word, tag in pos_tag(entry):
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word, tag_map[tag[0]])
            Final_words.append(word_Final)
    dataset.loc[index, 'text_final'] = str(Final_words)

# Map 'Yes'/'No' to 1/0
dataset['Have_Sarcasm'] = dataset['Have_Sarcasm'].map({'Yes': 1, 'No': 0})

# Apply undersampling to balance the classes
X = dataset['text_final']
y = dataset['Have_Sarcasm']
undersampler = RandomUnderSampler(random_state=42)
X_resampled, y_resampled = undersampler.fit_resample(np.array(X).reshape(-1, 1), y)

# Set parameters for the model
max_words = 1000
max_len = 150

# Define the LSTM model
def build_LSTM_model():
    model = Sequential()
    model.add(Embedding(max_words, 100, input_length=max_len))
    model.add(SpatialDropout1D(0.2))
    model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Instantiate the model
lstm_model = build_LSTM_model()

# Function to perform training and evaluation
def get_dataset_words_frequency(X_resampled, y_resampled, max_words, max_len):
    k = 5
    kf = KFold(n_splits=k, shuffle=True, random_state=1)
    acc_score = []
    all_predicted_targets = []
    all_actual_targets = []
    tprs = []
    mean_fpr = np.linspace(0, 1, 100)

    for train_index, test_index in kf.split(X_resampled):
        Train_X, Test_X = X_resampled[train_index], X_resampled[test_index]
        Train_Y, Test_Y = y_resampled[train_index], y_resampled[test_index]

        Train_X = [x[0] for x in Train_X]
        Test_X = [x[0] for x in Test_X]

        # Tokenization and padding of sequences
        tok = Tokenizer(num_words=max_words)
        tok.fit_on_texts(Train_X)
        sequences = tok.texts_to_sequences(Train_X)
        sequences_matrix = pad_sequences(sequences, maxlen=max_len)

        # Compile and train the model
        model = build_LSTM_model()
        model.fit(sequences_matrix, Train_Y, batch_size=100, epochs=10, validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss', min_delta=0.0001)])
        
        # Evaluate the model
        test_sequences = tok.texts_to_sequences(Test_X)
        test_sequences_matrix = pad_sequences(test_sequences, maxlen=max_len)
        predictions = model.predict(test_sequences_matrix).round().flatten()

        # ROC Curve
        fpr, tpr, _ = roc_curve(Test_Y, predictions)
        tprs.append(np.interp(mean_fpr, fpr, tpr))
        tprs[-1][0] = 0.0
        roc_auc = auc(fpr, tpr)
        
        # Store actual and predicted values
        all_predicted_targets.extend(predictions)
        all_actual_targets.extend(Test_Y)

    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)

    return mean_fpr, mean_tpr, mean_auc, all_predicted_targets, all_actual_targets

# Get ROC data
mean_fpr_lstm_under, mean_tpr_lstm_under, mean_auc_lstm_under, all_predictions_lstm_under, all_actuals_lstm_under = get_dataset_words_frequency(X_resampled, y_resampled, max_words, max_len)

# Print classification report
print(classification_report(all_actuals_lstm_under, all_predictions_lstm_under))
# Out:
# Dataset loaded.
# NLTK data downloaded.
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/nekdilkhan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/nekdilkhan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/nekdilkhan/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/nekdilkhan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/nekdilkhan/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# /var/folders/y0/23chrxcn0d9dv4pxp6v708kr0000gn/T/ipykernel_1927/3644849483.py:38: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, "html.parser")
# Epoch 1/10
# 45/45 [==============================] - 28s 579ms/step - loss: 0.6122 - accuracy: 0.6581 - val_loss: 1.1947 - val_accuracy: 0.1372
# Epoch 2/10
# 45/45 [==============================] - 25s 554ms/step - loss: 0.3401 - accuracy: 0.8645 - val_loss: 0.5244 - val_accuracy: 0.7780
# Epoch 3/10
# 45/45 [==============================] - 25s 562ms/step - loss: 0.1539 - accuracy: 0.9492 - val_loss: 0.4282 - val_accuracy: 0.8574
# Epoch 4/10
# 45/45 [==============================] - 26s 575ms/step - loss: 0.1062 - accuracy: 0.9636 - val_loss: 0.3017 - val_accuracy: 0.9116
# Epoch 5/10
# 45/45 [==============================] - 26s 571ms/step - loss: 0.0821 - accuracy: 0.9720 - val_loss: 0.2864 - val_accuracy: 0.9197
# Epoch 6/10
# 45/45 [==============================] - 25s 555ms/step - loss: 0.0716 - accuracy: 0.9761 - val_loss: 0.2903 - val_accuracy: 0.9260
# 44/44 [==============================] - 2s 46ms/step
# Epoch 1/10
# 45/45 [==============================] - 27s 563ms/step - loss: 0.6252 - accuracy: 0.6466 - val_loss: 0.9857 - val_accuracy: 0.1760
# Epoch 2/10
# 45/45 [==============================] - 25s 554ms/step - loss: 0.3933 - accuracy: 0.8406 - val_loss: 0.6649 - val_accuracy: 0.7121
# Epoch 3/10
# 45/45 [==============================] - 27s 596ms/step - loss: 0.1881 - accuracy: 0.9368 - val_loss: 0.4167 - val_accuracy: 0.8574
# Epoch 4/10
# 45/45 [==============================] - 21s 455ms/step - loss: 0.1206 - accuracy: 0.9596 - val_loss: 0.3327 - val_accuracy: 0.8944
# Epoch 5/10
# 45/45 [==============================] - 15s 331ms/step - loss: 0.0951 - accuracy: 0.9682 - val_loss: 0.2690 - val_accuracy: 0.9323
# Epoch 6/10
# 45/45 [==============================] - 15s 344ms/step - loss: 0.0818 - accuracy: 0.9700 - val_loss: 0.2539 - val_accuracy: 0.9413
# Epoch 7/10
# 45/45 [==============================] - 15s 329ms/step - loss: 0.0680 - accuracy: 0.9770 - val_loss: 0.2998 - val_accuracy: 0.9314
# 44/44 [==============================] - 1s 31ms/step
# Epoch 1/10
# 45/45 [==============================] - 17s 348ms/step - loss: 0.6218 - accuracy: 0.6472 - val_loss: 1.1951 - val_accuracy: 0.0903
# Epoch 2/10
# 45/45 [==============================] - 16s 358ms/step - loss: 0.3609 - accuracy: 0.8424 - val_loss: 0.6425 - val_accuracy: 0.7148
# Epoch 3/10
# 45/45 [==============================] - 15s 341ms/step - loss: 0.1557 - accuracy: 0.9451 - val_loss: 0.3455 - val_accuracy: 0.8962
# Epoch 4/10
# 45/45 [==============================] - 15s 343ms/step - loss: 0.1070 - accuracy: 0.9641 - val_loss: 0.2548 - val_accuracy: 0.9305
# Epoch 5/10
# 45/45 [==============================] - 15s 344ms/step - loss: 0.0915 - accuracy: 0.9706 - val_loss: 0.3259 - val_accuracy: 0.9197
# 44/44 [==============================] - 1s 31ms/step
# Epoch 1/10
# 45/45 [==============================] - 16s 344ms/step - loss: 0.6337 - accuracy: 0.6317 - val_loss: 1.1456 - val_accuracy: 0.0821
# Epoch 2/10
# 45/45 [==============================] - 15s 344ms/step - loss: 0.4068 - accuracy: 0.8295 - val_loss: 0.7963 - val_accuracy: 0.6462
# Epoch 3/10
# 45/45 [==============================] - 15s 338ms/step - loss: 0.1755 - accuracy: 0.9402 - val_loss: 0.3551 - val_accuracy: 0.8935
# Epoch 4/10
# 45/45 [==============================] - 15s 345ms/step - loss: 0.1156 - accuracy: 0.9612 - val_loss: 0.3547 - val_accuracy: 0.9079
# Epoch 5/10
# 45/45 [==============================] - 15s 340ms/step - loss: 0.0980 - accuracy: 0.9679 - val_loss: 0.2969 - val_accuracy: 0.9323
# Epoch 6/10
# 45/45 [==============================] - 16s 349ms/step - loss: 0.0895 - accuracy: 0.9711 - val_loss: 0.2536 - val_accuracy: 0.9404
# Epoch 7/10
# 45/45 [==============================] - 16s 346ms/step - loss: 0.0786 - accuracy: 0.9743 - val_loss: 0.2547 - val_accuracy: 0.9404
# 44/44 [==============================] - 2s 33ms/step
# Epoch 1/10
# 45/45 [==============================] - 16s 344ms/step - loss: 0.6268 - accuracy: 0.6393 - val_loss: 1.3262 - val_accuracy: 0.0785
# Epoch 2/10
# 45/45 [==============================] - 15s 339ms/step - loss: 0.3791 - accuracy: 0.8369 - val_loss: 0.7137 - val_accuracy: 0.6742
# Epoch 3/10
# 45/45 [==============================] - 15s 340ms/step - loss: 0.1622 - accuracy: 0.9433 - val_loss: 0.3329 - val_accuracy: 0.8980
# Epoch 4/10
# 45/45 [==============================] - 15s 339ms/step - loss: 0.1175 - accuracy: 0.9609 - val_loss: 0.2193 - val_accuracy: 0.9413
# Epoch 5/10
# 45/45 [==============================] - 15s 342ms/step - loss: 0.0934 - accuracy: 0.9679 - val_loss: 0.2070 - val_accuracy: 0.9531
# Epoch 6/10
# 45/45 [==============================] - 16s 358ms/step - loss: 0.0759 - accuracy: 0.9740 - val_loss: 0.1712 - val_accuracy: 0.9549
# Epoch 7/10
# 45/45 [==============================] - 16s 348ms/step - loss: 0.0744 - accuracy: 0.9758 - val_loss: 0.2296 - val_accuracy: 0.9486
# 44/44 [==============================] - 2s 32ms/step
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      3460
#            1       0.97      0.92      0.95      3460
#
#     accuracy                           0.95      6920
#    macro avg       0.95      0.95      0.95      6920
# weighted avg       0.95      0.95      0.95      6920

# %%
# Plot Combined ROC Curve
plt.figure()
plt.plot(mean_fpr_lstm, mean_tpr_lstm, color='blue', lw=2, label='ROC curve LSTM Oversampling (area = %0.2f)' % mean_auc_lstm)
plt.plot(mean_fpr_lstm_under, mean_tpr_lstm_under, color='green', lw=2, label='ROC curve LSTM Undersampling (area = %0.2f)' % mean_auc_lstm_under)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Combined ROC Curve for LSTM')
plt.legend(loc="lower right")
plt.show()

# %%
import matplotlib.pyplot as plt
# Plot Combined ROC Curve
plt.figure()
plt.plot(mean_fpr_lstm, mean_tpr_lstm, color='blue', lw=2, label='ROC curve LSTM Oversampling (area = %0.2f)' % mean_auc_lstm)
plt.plot(mean_fpr_lstm_under, mean_tpr_lstm_under, color='green', lw=2, label='ROC curve LSTM Undersampling (area = %0.2f)' % mean_auc_lstm_under)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Combined ROC Curve for LSTM')
plt.legend(loc="lower right")
# Save the plot
plt.savefig('combined_roc_curve_lstm.png', dpi=300)
plt.show()
